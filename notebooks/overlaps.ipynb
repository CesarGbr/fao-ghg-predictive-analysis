# %%
import pandas as pd

df = pd.read_csv('../results/overlap_correlaciones.csv', sep=',')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19613 entries, 0 to 19612
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Cluster            19613 non-null  int64
#  1   País_1             19613 non-null  object
#  2   País_2             19613 non-null  object
#  3   Años_overlap       19613 non-null  int64
#  4   Años_min_común     19613 non-null  int64
#  5   Años_max_común     19613 non-null  int64
#  6   Productos_comunes  19613 non-null  int64
#  7   Correlación        19592 non-null  float64
#  8   Años_solo_P1       19613 non-null  int64
#  9   Años_solo_P2       19613 non-null  int64
#  10  Rango_solo_P1      19613 non-null  object
#  11  Rango_solo_P2      19613 non-null  object
# dtypes: float64(1), int64(7), object(4)
# memory usage: 1.8+ MB
