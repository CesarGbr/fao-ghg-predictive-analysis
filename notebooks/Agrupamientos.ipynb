# %%
import pandas as pd

df = pd.read_csv('../results/paises_agrupados_por_completitud.csv', sep=',')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   País                   280 non-null    object
#  1   Año_min                280 non-null    int64
#  2   Año_max                280 non-null    int64
#  3   Años_span              280 non-null    int64
#  4   Años_únicos            280 non-null    int64
#  5   Continuidad_%          280 non-null    float64
#  6   N_productos            280 non-null    int64
#  7   N_elementos            280 non-null    int64
#  8   N_combos_prod_elem     280 non-null    int64
#  9   Cobertura_productos_%  280 non-null    float64
#  10  Cobertura_elementos_%  280 non-null    float64
#  11  Registros_totales      280 non-null    int64
#  12  Densidad_datos_%       280 non-null    float64
#  13  Registros_pre1990      280 non-null    int64
# ...
