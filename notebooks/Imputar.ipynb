# %%
import pandas as pd

df = pd.read_csv('../results/candidatos_imputacion.csv', sep=',')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Cluster            20 non-null     int64
#  1   País_1             20 non-null     object
#  2   País_2             20 non-null     object
#  3   Años_overlap       20 non-null     int64
#  4   Años_min_común     20 non-null     int64
#  5   Años_max_común     20 non-null     int64
#  6   Productos_comunes  20 non-null     int64
#  7   Correlación        20 non-null     float64
#  8   Años_solo_P1       20 non-null     int64
#  9   Años_solo_P2       20 non-null     int64
#  10  Rango_solo_P1      20 non-null     object
#  11  Rango_solo_P2      20 non-null     object
# dtypes: float64(1), int64(7), object(4)
# memory usage: 2.0+ KB
